# %% [markdown]
# # L40 · 求职与作品集：去 SOTA 上班
#
# **学习目标**
# - 复盘 40 节课构建的能力地图
# - 理解 SOTA 级 AI 公司看重什么、如何准备作品集
# - 产出一份「能力自测清单」与求职行动路线
#
# **前置依赖**：全部 1-39 课
# **预计时长**：60 分钟
# **技术栈**：纯 Python（生成自测报告，离线）
#
# ---
#
# ## 收官致辞：你已走完从零到 SOTA 的路
#
# 40 节课前，你不会写一行 Python。今天，你已经亲手做过：
# - **编程与工程**：变量、函数、类、HTTP、FastAPI、数据库、鉴权、部署
# - **数据与 AI 直觉**：numpy、pandas、可视化、概率、第一性原理、ML 模型
# - **大模型应用**：Prompt、函数调用、RAG、Agent、微调
# - **工程化约束 AI**：评测、护栏、可观测、安全对齐、成本、MLOps
# - **后训练与 RL**：SFT、奖励模型、DPO、PPO、RLHF、RL 项目
# - **综合项目**：RAG 助手、多 Agent、后训练管线
#
# 这，正是 SOTA 公司 AI 工程师的日常能力栈。

# %% [markdown]
# ## 第一步：能力地图（自动生成）

# %%
skills = {
    "编程基础": ["L01 变量", "L03 函数", "L06 OOP"],
    "Web工程": ["L13 HTTP", "L14 FastAPI", "L16 DB", "L17 鉴权", "L18 部署"],
    "数据AI直觉": ["L07 numpy", "L08 pandas", "L12 ML模型"],
    "大模型应用": ["L19 Transformer", "L20 Prompt", "L22 RAG", "L23 Agent", "L24 微调"],
    "约束与安全": ["L25 评测", "L26 护栏", "L28 对齐", "L30 MLOps"],
    "后训练RL": ["L31 SFT", "L32 RM", "L33 DPO", "L35 RLHF", "L36 RL项目"],
    "综合项目": ["L37 RAG助手", "L38 多Agent", "L39 管线"],
}
total = sum(len(v) for v in skills.values())
print(f"🗺️  你的能力地图：{len(skills)} 大模块，共 {total} 项硬技能")
for k, v in skills.items():
    print(f"  ▪ {k}：{len(v)} 项")

# %% [markdown]
# ## 第二步：作品集建议（从本课产出）

# %%
portfolio = [
    ("企业知识库 RAG 助手", "L37", "展示检索+护栏+API 全栈能力"),
    ("多 Agent 协作系统", "L38", "展示系统设计/角色编排"),
    ("端到端后训练流水线", "L39", "展示对齐算法工程化能力"),
    ("AI 安全红队报告", "L28", "展示安全与对齐意识"),
]
for name, src, why in portfolio:
    print(f"  📁 {name}（来自 {src}）：{why}")

# %% [markdown]
# # 🎯 AHA 顿悟单元格：你的「求职能力护照」
#
# 运行下面代码。计算机会生成一份**你的能力自测护照**：逐项列出 7 大模块、每项是否已覆盖、
# 并给出「是否具备去 SOTA 面试」的综合判定。这是你 40 节课的毕业典礼。
#
# > 从「不会 Python」到「握有一份 AI 工程师能力护照」，你只用了 40 节课。下一步，是把它变成真offer。

# %%
# ===== 运行我！生成你的能力护照 =====
print("  🎓 毕业生能力护照 · NativeAI Zero-to-Hero\n")
print("  " + "=" * 50)
all_pass = True
for k, v in skills.items():
    status = "✅ 已覆盖" if len(v) >= 3 else "⚠️ 待加强"
    if len(v) < 3: all_pass = False
    print(f"  {k:<12} [{status}]  {len(v)} 项技能")
print("  " + "=" * 50)
if all_pass:
    print("  🏅 综合评定：具备去 SOTA 级 AI 公司面试的扎实基础！")
    print("  🚀 下一步行动：精选 3 个作品上 GitHub + 刷 RLHF/LLM 面试题 + 投递。")
else:
    print("  📌 个别模块可回看对应课时补强，再战。")
print("\n  🌟 恭喜毕业！你已从一个纯新手，成长为能造 AI 的工程师。")

# %% [markdown]
# # 📝 讲师备课笔记（接手 Agent 专用）
#
# **本课定位**：收官课，整合全课程为求职资产；情绪价值高，AHA 是「毕业护照」。
# **易错点**：`skills` 字典与前面课时编号需一致；本方案硬编码，若新增课时需同步更新映射。
# **AHA 机制**：能力护照+综合判定，强「我真的毕业了」仪式感与行动指引。
# **衔接**：无后续课时（课程终点）；可建议学员进入真实开源项目（如 HuggingFace TRL、LangChain）继续。
# **依赖**：纯 Python 标准库。
# **SOTA 求职补充**：备课笔记应附真实岗位能力要求（如掌握 PyTorch、Transformer 源码、分布式训练、RLHF 经验），指引学员下一阶段深耕方向。

# %% [markdown]
# # 📚 课程完结 · 下一步你该做什么
#
# 1. **作品上云**：把 L37/L38/L39 三个项目整理成 GitHub 仓库，写 README。
# 2. **深挖真框架**：用 PyTorch 复现 L31-L35 的算法；读 Llama/Phi 模型源码。
# 3. **刷面试题**：RLHF 流程、Attention 数学、分布式训练、评测指标。
# 4. **投简历**：瞄准 AI 应用工程师 / 对齐工程师 / MLOps 工程师岗位。
#
# **你已不再是零基础。你是一名能造 AI 的工程师。去吧，去 SOTA。**
